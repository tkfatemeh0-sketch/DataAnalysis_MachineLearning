# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker
import os

# %%
src_file = os.path.join('data', 'raw', 'EPA_fuel_economy.csv')
image_dir = ('images')

# %%
df = pd.read_csv(src_file)
df.head()
# Out:
#     make     model  year  cylinders            trany  displ       VClass  co2  \
# 0  Acura       NSX  2000        6.0  Automatic 4-spd    3.0  Two Seaters   -1
# 1  Acura       NSX  2000        6.0     Manual 6-spd    3.2  Two Seaters   -1
# 2    BMW   M Coupe  2000        6.0     Manual 5-spd    3.2  Two Seaters   -1
# 3    BMW  Z3 Coupe  2000        6.0  Automatic 4-spd    2.8  Two Seaters   -1
# 4    BMW  Z3 Coupe  2000        6.0     Manual 5-spd    2.8  Two Seaters   -1
#
#    barrels08  fuelCost08 fuelType  highway08  city08  comb08
# 0  18.311667        2600  Premium         22      15      18
# 1  18.311667        2600  Premium         22      15      18
# 2  17.347895        2500  Premium         23      17      19
# 3  17.347895        2500  Premium         24      17      19
# 4  17.347895        2500  Premium         24      17      19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24210 entries, 0 to 24209
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   make        24210 non-null  object
#  1   model       24210 non-null  object
#  2   year        24210 non-null  int64
#  3   cylinders   23979 non-null  float64
#  4   trany       24201 non-null  object
#  5   displ       23980 non-null  float64
#  6   VClass      24210 non-null  object
#  7   co2         24210 non-null  int64
#  8   barrels08   24210 non-null  float64
#  9   fuelCost08  24210 non-null  int64
#  10  fuelType    24210 non-null  object
#  11  highway08   24210 non-null  int64
#  12  city08      24210 non-null  int64
#  13  comb08      24210 non-null  int64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 2.6+ MB

# %%
#Combined fuel consumption, both in the city and on the highway
n, bins, patches=plt.hist(df['comb08'],range=(10,50), bins=50)

# %%
print(n)
print(bins)
# Out:
# [  32.  104.  282.  442.    0. 1077. 1328. 1479. 1407.    0. 1921. 2097.
#  2022. 2307.    0. 1709. 1399. 1196. 1018.    0.  849.  659.  554.  479.
#     0.  413.  217.  277.  131.    0.  115.   66.   66.   28.    0.   31.
#    30.   42.   39.    0.   37.    6.   12.    0.    0.   21.   11.   10.
#     4.   16.]
# [10.  10.8 11.6 12.4 13.2 14.  14.8 15.6 16.4 17.2 18.  18.8 19.6 20.4
#  21.2 22.  22.8 23.6 24.4 25.2 26.  26.8 27.6 28.4 29.2 30.  30.8 31.6
#  32.4 33.2 34.  34.8 35.6 36.4 37.2 38.  38.8 39.6 40.4 41.2 42.  42.8
#  43.6 44.4 45.2 46.  46.8 47.6 48.4 49.2 50. ]

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'], range=(10,50), histtype='step', orientation='horizontal');
ax.set_xlabel('Number of cars')
ax.set_ylabel('Combined Fuel Economy (MPG)')
ax.set_title('Combined Fuel Economy ')
# Out:
# Text(0.5, 1.0, 'Combined Fuel Economy ')

# %%
fig, ax = plt.subplots(2)
ax[0].hist(df['comb08'], range=(10,50))
ax[1].hist(df['comb08'], range=(10,100));

# %%
fig, ax = plt.subplots(1,2,figsize=(12,5))
ax[0].boxplot(df['comb08'], labels=['All'], showfliers=False)
ax[0].set(title='MPG Distribution', ylabel='MPG for vehicles')
ax[1].boxplot(df['comb08'], labels=['All'])
ax[1].set(title='MPG Distribution', ylabel='MPG for vehicles');
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19040\2644573570.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax[0].boxplot(df['comb08'], labels=['All'], showfliers=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_19040\2644573570.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax[1].boxplot(df['comb08'], labels=['All'])
